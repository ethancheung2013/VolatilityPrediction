# %%
from selenium import webdriver
# from selenium.webdriver.support.ui import WebDriverWait

# %%
# driver = webdriver.Safari()
driver = webdriver.Chrome()

# %%
url = 'http://finance.yahoo.com/news/provider-marketwatch/'
# nextPage = driver.find_element_by_link_text("Next >>")
driver.get(url)
# print driver.page_source

# %%
nextPage = driver.find_element_by_link_text("Next >>")
nextPage.click()
driver.get_cookies()
# for i, element in enumerate(driver.find_element_by_class_name('txt')):
# print driver.find_element_by_class_name('txt').text
# Out:
# [{u'domain': u'.yahoo.com',
#   u'expiry': 1467531117.179782,
#   u'name': u'B',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'dk6l9l19ra1nc&b=3&s=eu'},
#  {u'domain': u'.yahoo.com',
#   u'expiry': 1467531121.99105,
#   u'name': u'RMBX',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'dk6l9l19ra1nc&b=3&s=eu&t=183'},
#  {u'domain': u'.yahoo.com',
#   u'expiry': 1736668800,
#   u'name': u'ucs',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'bnas=0'},
#  {u'domain': u'finance.yahoo.com',
#   u'expiry': 1498980732,
#   u'name': u'ywadp10001840545256',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'2708177121'},
#  {u'domain': u'finance.yahoo.com',
#   u'expiry': 1435908739,
#   u'name': u'fpc10001840545256',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'ZaF0Ynnw|BOkBJD2Naa|fses10001840545256=|BOkBJD2Naa|ZaF0Ynnw|fvis10001840545256=|8TYTMHsHMo|8TYTMHsHMo|8TYTMHsHMo|8|8TYTMHsHMo|8TYTMHsHMo'},
#  {u'domain': u'.wsod.com',
#   u'expiry': 1409556720.971786,
#   u'name': u'ub',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'B045953b506f08709c:14:1280:800'},
#  {u'domain': u'.wsod.com',
#   u'expiry': 1407051120.971871,
#   u'name': u'fp',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'!!!!4:95845s45s50'},
#  {u'domain': u'.wsod.com',
#   u'expiry': 1562052726.306551,
#   u'name': u's',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'a1111b2211v26'},
#  {u'domain': u'.wsod.com',
#   u'expiry': 1407051136.654171,
#   u'name': u'g51015',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'2:1109:940:132:0::1404372736:B2|2:1109:940:132:0::1404372729:B2|2:1109:940:132:0::1404372720:B2!!!!!!'},
#  {u'domain': u'.wsod.com',
#   u'expiry': 1407051136.813165,
#   u'name': u'g1518',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'46:2906:2877:532:0::1404372736:B2|30:3778:3495:710:0::1404372734:B2|46:2906:3013:532:0::1404372729:B2|30:3778:3495:710:0::1404372726:B2|46:2906:2877:532:0::1404372720:B2!!!!!!'},
#  {u'domain': u'.wsod.com',
#   u'expiry': 1407051137.726172,
#   u'name': u'g36013',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'22:394:607:158:0::1404372737:B2|22:394:603:158:0::1404372737:B2|8:94:381:49:0::1404372734:B2!!!!!!'},
#  {u'domain': u'.scorecardresearch.com',
#   u'expiry': 1466580725.857164,
#   u'name': u'UID',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'3c2c75-107.14.47.123-1404372725'},
#  {u'domain': u'.scorecardresearch.com',
#   u'expiry': 1466580725.857311,
#   u'name': u'UIDR',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'1404372725'},
#  {u'domain': u'.scorecardresearch.com',
#   u'expiry': 1406964732.065448,
#   u'name': u'CP3',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'1'},
#  {u'domain': u'.dmtry.com',
#   u'expiry': 1435822321.291733,
#   u'name': u'aid',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'Ce64e64ee20140703033200505'},
#  {u'domain': u'.interclick.com',
#   u'expiry': 2351143920.644847,
#   u'name': u'T',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'1'},
#  {u'domain': u'.interclick.com',
#   u'expiry': 2351143921.319902,
#   u'name': u'uid',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'u=2e44eff3-e69d-4586-8668-134514d23ecf'},
#  {u'domain': u'.a1.interclick.com',
#   u'expiry': 

#   u'path': u'/',
#   u'secure': False,
#   u'value': u'e9=16261&e11=16261&o9=&o11='},
#  {u'domain': u'.interclick.com',
#   u'expiry': 1719991939.143123,
#   u'name': u'sgm',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'25442=735416'},
#  {u'domain': u'.turn.com',
#   u'expiry': 1419924735,
#   u'name': u'rrs',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'6'},
#  {u'domain': u'.turn.com',
#   u'expiry': 1419924735,
#   u'name': u'rds',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'16254'},
#  {u'domain': u'.turn.com',
#   u'expiry': 1419924735,
#   u'name': u'rv',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'1'},
#  {u'domain': u'.turn.com',
#   u'expiry': 1419924739.00223,
#   u'name': u'uid',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'4597680721750548614'},
#  {u'domain': u'.analytics.yahoo.com',
#   u'name': u'itsc',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'BOkBJD2Naa|ZaF0Ynnw|fvis10001840545256=|8TYTMHsHMo|8TYTMHsHMo|8TYTMHsHMo|8|8TYTMHsHMo|8TYTMHsHMo'},
#  {u'domain': u'ucs.query.yahoo.com',
#   u'name': u'X-AC',
#   u'path': u'/v1/public',
#   u'secure': False,
#   u'value': u'D'},
#  {u'domain': u'.doubleclick.net',
#   u'expiry': 1467444722.154263,
#   u'name': u'id',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'ce14d2a550000cf||t=1404372721|et=730|cs=002213fd4822d9068ddfa88b15'},
#  {u'domain': u'.dlqm.net',
#   u'expiry': 1440372737.256423,
#   u'name': u'ASD1',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'58142757-11-U7UG8FO1BvlTtQcA_'},
#  {u'domain': u'.questionmarket.com',
#   u'expiry': 1404376337.170992,
#   u'name': u'linkjumptest',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'1'},
#  {u'domain': u'.questionmarket.com',
#   u'name': u'endsurvey',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'no'},
#  {u'domain': u'ads.yahoo.com',
#   u'expiry': 1406964721.990882,
#   u'name': u'uid',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'uid=1f635e58-0284-11e4-8673-23368304fd00&_hmacv=1&_salt=2364270615&_keyid=k1&_hmac=3a1e2496e853217f5713c552508a5c4f4e495135'},
#  {u'domain': u'ads.yahoo.com',
#   u'expiry': 1467444730.18753,
#   u'name': u'pv1',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'"b!!!!$!\'\'!<!!!?,!)FOv!N:(u!/?uu!!!%%!?5%!!?mK)!ZmB)!1]?R!2/-I~~~~~~>qgm#~~!#qFa%+PJ8!(QgD!KU_#!/N^3!!!%%!?5%!!?mK)![:Z-!!28T!2GY^~~~~~~>qgm,>ub_<M.jTN"'},
#  {u'domain': u'ads.yahoo.com',
#   u'expiry': 1404432001.187564,
#   u'name': u'liday1',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u')l%M?N>6P`NJ=lHTuL5$'},
#  {u'domain': u'ads.yahoo.com',
#   u'expiry': 1467444737.53796,
#   u'name': u'ih',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'"b!!!!%!=W@E!!!!#>qgm3!>D>N!!!!#>qgm#!P3OQ!!!!#>qgm,"'},
#  {u'domain': u'ads.yahoo.com',
#   u'expiry': 1404432000.538025,
#   u'name': u'vuday1',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'!!w[0NJ=lHpyo5>'},
#  {u'domain': u'ads.yahoo.com',
#   u'expiry': 1467444739.352499,
#   u'name': u'bh',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'"b!!!!*!%Clh!!!!#>qgm5!%s-u!!!!#>qgm4!%t?K!!!!#>qgm-!\')p3!!!!%>qgm-!\')qB!!!!#>qgm#!\')w0!!!!#>qgm$!\')w1!!!!#>qgm4"'},
#  {u'domain': u'.atdmt.com',
#   u'expiry': 1467417601.554614,
#   u'name': u'AA002',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'1404372722-6297250'},
#  {u'domain': u'.atdmt.com',
#   u'expiry': 1467417601.554717,
#   u'name': u'MUID',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'0FA6F64DDD1B60D51FF6F021DE1B602F'},
#  {u'domain': u'.atdmt.com',
#   u'expiry': 1467417601.554761,
#   u'name': u'ATN',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'1.1404372722.16261422203969744933.AYKhfo29K-cmd6BjJxo'},
#  {u'domain': u'.agkn.com',
#   u'expiry': 1562052723.035722,
#   u'name': u'uuid',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'993475441688906806'},
#  {u'domain': u'.agkn.com',
#   u'expiry': 1467444723.035832,
#   u'name': u'u',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'B|0SAobR8NyG0fDcgAAAAAAAAABAhEBEmGOAgABBvsAAAAkMmU0NGVmZjMtZTY5ZC00NTg2LTg2NjgtMTM0NTE0ZDIzZWNmAAA'},
#  {u'domain': u'.bluekai.com',
#   u'expiry': 1419924723.056052,
#   u'name': u'bkdc',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'snv'},
#  {u'domain': u'.bluekai.com',
#   u'expiry': 1419924726.116994,
#   u'name': u'bklc',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'53b506f5'},
#  {u'domain': u'.bluekai.com',
#   u'expiry': 1419924726.117025,
#   u'name': u'bko',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'KJpEDsjQI13tBjiHyzsJcXGY9evPOmD='},
#  {u'domain': u'.bluekai.com',
#   u'expiry': 1419924730.716618,
#   u'name': u'bkw5',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'KJpqrJVOQjc7wyLeWe90neAJ/+1aM0Gy15pRQi0pIyHYhQzGG0QcApkycYcpq9TeytvTp/7PWJ7oEAy19JOma46='},
#  {u'domain': u'.bluekai.com',
#   u'expiry': 1419924738.467846,
#   u'name': u'bkc',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u''},
#  {u'domain': u'.bluekai.com',
#   u'expiry': 1419924738.467938,
#   u'name': u'bkst',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'KJhMR5MchzYQyZYHRoHiqJsuGorRqsvCS8vuqvogAjHZgs+rSJZDjs0KSZaoA435qVLyYX1CLc3MPOmENeuQQkxp0hH5WN1n1N6n1p1nUDBMWNBeAhxMT2EABYjtAw3kl9y16QpmM3fOgFTVSDaZOGPPSPchsucj7CPmMCDHn3b1RsVFhHARtOkvXfnpXLFpFGJ+LMEOWeogQuRW9cDXBJD='},
#  {u'domain': u'.bluekai.com',
#   u'expiry': 1419924738.468005,
#   u'name': u'bku',
#   u'path': u'/',
#   u'secure': False,
#   u'value': u'yQG99w/s+PmfRnoC'}]

# %%
driver.back()

# %%
#     for i, element in enumerate(driver.find_elements_by_class_name('txt')):
#         #print element.text   #get_attribute('href')
#         if i ==0:
#             print element.find_element_by_tag_name('a').text
#             iURL = element.find_element_by_tag_name('a').get_attribute('href')
#             driver.get(iURL)
#             # first look for 'article'
#             mainStory = driver.find_element_by_tag_name('article')
#             print mainStory.find_element_by_tag_name('p').text

# %%
# # driver = webdriver.Safari()
# driver = webdriver.Chrome()

# numPages = 1
# TOTAL = 3
# while numPages < TOTAL:
#     if numPages == 1:
#         url = 'http://finance.yahoo.com/news/provider-marketwatch/'
#         driver.get(url)
        
#         print 'in 1', driver.get_cookies()
#     elif numPages > 1:

#         element = driver.find_element_by_link_text("Next >>")
#         print "clicking", element
#         driver.implicitly_wait(5)
#         element.click()
# #         url = element.get_attribute('href')
#         print 'in 2', driver.get_cookies()
#     numPages += 1
        
    

#     for i, element in enumerate(driver.find_elements_by_class_name('txt')):
#         if i == 0:  # for testing just print first element
#             print element.find_element_by_tag_name('a').text
#             iURL = element.find_element_by_tag_name('a').get_attribute('href')
#             driver.get(iURL)
#             # first look for 'article'
#             mainStory = driver.find_element_by_tag_name('article')
#             print mainStory.find_element_by_tag_name('p').text

#     driver.back()
#     print "waiting bfore next"
#     driver.implicitly_wait(10)
#     print 'numPages ',numPages, TOTAL
